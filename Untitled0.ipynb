# %% [markdown]
# <a href="https://colab.research.google.com/github/Gio10Ste/EverPeak-analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola EverPeak desde Colab")
# Out:
# Hola EverPeak desde Colab
